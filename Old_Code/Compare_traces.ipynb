# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import seaborn as sns
import os

from glob import glob

Alex_a=pd.read_csv('C:\\Users\\v35431nc\\Documents\\Lab_Stuff\\Code\\tissue_image_analysis\\tissue_image_analysis\\Output\\130522_1_GG_GFPTub-CheHis_uf_8p6_MP_fr1\\Alex_a\\Data\\130522_1_fr1_cell_data_geometry.csv')
Alex_b=pd.read_csv('C:\\Users\\v35431nc\\Documents\\Lab_Stuff\\Code\\tissue_image_analysis\\tissue_image_analysis\\Output\\130522_1_GG_GFPTub-CheHis_uf_8p6_MP_fr1\\Alex_b\\Data\\130522_1_fr1_cell_data_geometry.csv')

Gina_a=pd.read_csv('C:\\Users\\v35431nc\\Documents\\Lab_Stuff\\Code\\tissue_image_analysis\\tissue_image_analysis\\Output\\130522_1_GG_GFPTub-CheHis_uf_8p6_MP_fr1\\Gina_a\\Data\\130522_1_fr1_cell_data_geometry.csv')
Gina_b=pd.read_csv('C:\\Users\\v35431nc\\Documents\\Lab_Stuff\\Code\\tissue_image_analysis\\tissue_image_analysis\\Output\\130522_1_GG_GFPTub-CheHis_uf_8p6_MP_fr1\\Gina_b\\Data\\130522_1_fr1_cell_data_geometry.csv')
Gina_c=pd.read_csv('C:\\Users\\v35431nc\\Documents\\Lab_Stuff\\Code\\tissue_image_analysis\\tissue_image_analysis\\Output\\130522_1_GG_GFPTub-CheHis_uf_8p6_MP_fr1\\Gina_c\\Data\\130522_1_fr1_cell_data_geometry.csv')

Henry_a=pd.read_csv('C:\\Users\\v35431nc\\Documents\\Lab_Stuff\\Code\\tissue_image_analysis\\tissue_image_analysis\\Output\\130522_1_GG_GFPTub-CheHis_uf_8p6_MP_fr1\\Henry_a\\Data\\130522_1_fr1_cell_data_geometry.csv')

Tash_a=pd.read_csv('C:\\Users\\v35431nc\\Documents\\Lab_Stuff\\Code\\tissue_image_analysis\\tissue_image_analysis\\Output\\130522_1_GG_GFPTub-CheHis_uf_8p6_MP_fr1\\Tash_a\\Data\\130522_1_fr1_cell_data_geometry.csv')

Sarah_a=pd.read_csv('C:\\Users\\v35431nc\\Documents\\Lab_Stuff\\Code\\tissue_image_analysis\\tissue_image_analysis\\Output\\130522_1_GG_GFPTub-CheHis_uf_8p6_MP_fr1\\Sarah_a\\Data\\130522_1_fr1_cell_data_geometry.csv')

cp_cyto_a=pd.read_csv('C:\\Users\\v35431nc\\Documents\\Lab_Stuff\\Code\\tissue_image_analysis\\tissue_image_analysis\\Output\\130522_1_GG_GFPTub-CheHis_uf_8p6_MP_fr1\\cp_cyto_a\\Data\\130522_1_fr1_cell_data_geometry.csv')
cp_cyto2_a=pd.read_csv('C:\\Users\\v35431nc\\Documents\\Lab_Stuff\\Code\\tissue_image_analysis\\tissue_image_analysis\\Output\\130522_1_GG_GFPTub-CheHis_uf_8p6_MP_fr1\\cp_cyto2_a\\Data\\130522_1_fr1_cell_data_geometry.csv')

# %%
Alex_a['trace_name']='Alex a'
Alex_b['trace_name']='Alex b'
Gina_a['trace_name']='Gina a'
Gina_b['trace_name']='Gina b'
Gina_c['trace_name']='Gina c'
Sarah_a['trace_name']='Sarah'
Henry_a['trace_name']='Henry'
Tash_a['trace_name']='Tash'
cp_cyto_a['trace_name']='Cellpose cyto'
cp_cyto2_a['trace_name']='Cellpose cyto2'

# %%
data=pd.concat([Alex_a,Alex_b, Gina_a, Gina_b, Gina_c, Sarah_a, Henry_a,Tash_a, cp_cyto_a, cp_cyto2_a], ignore_index=True)

# %%
sns.countplot(x=data["trace_name"])
plt.ylabel('cell count')
plt.xticks(rotation=90)
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
sns.countplot(data=data, x="cell_edge_count", hue="trace_name")
# Out:
# <AxesSubplot: xlabel='cell_edge_count', ylabel='count'>

# %%
edge_counts = (data.groupby(['trace_name'])['cell_edge_count']
                     .value_counts(normalize=True)
                     .rename('percentage')
                     .reset_index())
p = sns.barplot(x="cell_edge_count", y="percentage", hue="trace_name", data=edge_counts)
p.xlabel=('cell edge count')
p.ylabel=('Fracation of total cells')
_ = plt.setp(p.get_xticklabels(), rotation=0) 
plt.legend(loc='upper right')

# %%
edge_counts
# Out:
#         trace_name  cell_edge_count  percentage
# 0           Alex a              6.0    0.496528
# 1           Alex a              5.0    0.229167
# 2           Alex a              7.0    0.187500
# 3           Alex a              8.0    0.045139
# 4           Alex a              4.0    0.038194
# 5           Alex a              9.0    0.003472
# 6           Alex b              6.0    0.481229
# 7           Alex b              5.0    0.249147
# 8           Alex b              7.0    0.197952
# 9           Alex b              8.0    0.037543
# 10          Alex b              4.0    0.030717
# 11          Alex b              9.0    0.003413
# 12   Cellpose cyto              6.0    0.445183
# 13   Cellpose cyto              5.0    0.252492
# 14   Cellpose cyto              7.0    0.209302
# 15   Cellpose cyto              4.0    0.046512
# 16   Cellpose cyto              8.0    0.043189
# 17   Cellpose cyto             10.0    0.003322
# 18  Cellpose cyto2              6.0    0.463333
# ...

# %%
48

# %%
data.groupby(['cell_edge_count','trace_name']).count().cell_id
# Out:
# cell_edge_count  trace_name
# 4.0              Alex a             11
#                  Alex b              9
#                  Cellpose cyto      14
#                  Cellpose cyto2     14
#                  Gina a             14
#                  Gina b             10
#                  Gina c              7
#                  Henry               8
#                  Sarah              11
# 5.0              Alex a             66
#                  Alex b             73
#                  Cellpose cyto      76
#                  Cellpose cyto2     70
#                  Gina a             68
#                  Gina b             72
#                  Gina c             62
#                  Henry              67
#                  Sarah              74
# 6.0              Alex a            143
#                  Alex b            141
#                  Cellpose cyto     134
#                  Cellpose cyto2    139
#                  Gina a            119
# ...

# %%
cell_edge_percent=data.groupby(['cell_edge_count','trace_name']).count().cell_id/data.groupby('trace_name').count().cell_id

# %%
data.groupby('trace_name').count().cell_id
# Out:
# trace_name
# Alex a            288
# Alex b            293
# Cellpose cyto     301
# Cellpose cyto2    300
# Gina a            277
# Gina b            271
# Gina c            254
# Henry             261
# Sarah             275
# Tash              291
# Name: cell_id, dtype: int64

# %%
cell_edge_percent
# Out:
# cell_edge_count  trace_name
# 4.0              Alex a            0.038194
#                  Alex b            0.030717
#                  Cellpose cyto     0.046512
#                  Cellpose cyto2    0.046667
#                  Gina a            0.050542
#                  Gina b            0.036900
#                  Gina c            0.027559
#                  Henry             0.030651
#                  Sarah             0.040000
# 5.0              Alex a            0.229167
#                  Alex b            0.249147
#                  Cellpose cyto     0.252492
#                  Cellpose cyto2    0.233333
#                  Gina a            0.245487
#                  Gina b            0.265683
#                  Gina c            0.244094
#                  Henry             0.256705
#                  Sarah             0.269091
# 6.0              Alex a            0.496528
#                  Alex b            0.481229
#                  Cellpose cyto     0.445183
# ...

# %%
data[['cell_id','trace_name', 'cell_edge_count']].groupby(['trace_name','cell_edge_count']).count()
# Out:
#                                 cell_id
# trace_name     cell_edge_count
# Alex a         4.0                   11
#                5.0                   66
#                6.0                  143
#                7.0                   54
#                8.0                   13
#                9.0                    1
# Alex b         4.0                    9
#                5.0                   73
#                6.0                  141
#                7.0                   58
#                8.0                   11
#                9.0                    1
# Cellpose cyto  4.0                   14
#                5.0                   76
#                6.0                  134
#                7.0                   63
#                8.0                   13
#                10.0                   1
# Cellpose cyto2 4.0                   14
#                5.0                   70
#                6.0                  139
#                7.0                   64
# ...

# %%
sns.boxplot(data=data, x='cell_area_microns', y='trace_name', showmeans=True,            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"5"})
# Out:
# <AxesSubplot: xlabel='cell_area_microns', ylabel='trace_name'>

# %%
sns.boxplot(data=data, x='circularity', y='trace_name', showmeans=True,            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"5"})
# Out:
# <AxesSubplot: xlabel='circularity', ylabel='trace_name'>

# %%
sns.histplot(data=data, x='circularity', hue='trace_name')
# Out:
# <AxesSubplot: xlabel='circularity', ylabel='Count'>

# %%
data.columns
# Out:
# Index(['cell_id', 'cell_perimeter_microns', 'cell_area_microns',
#        'shape_parameter', 'circularity', 'cell_edge_count',
#        'major_shape_axis_alignment_rads', 'trace_name'],
#       dtype='object')

# %%
sns.histplot(data=data, x='major_shape_axis_alignment_rads', hue='trace_name')
# Out:
# <AxesSubplot: xlabel='major_shape_axis_alignment_rads', ylabel='Count'>

# %%
g = sns.FacetGrid(data, col="trace_name", height=2.5, col_wrap=3)
g.map(sns.histplot, "major_shape_axis_alignment_rads", stat='probability')

# %%
g = sns.FacetGrid(data, col="trace_name", height=2.5, col_wrap=3)
g.map(sns.histplot, "circularity", stat='probability')

# %%
g = sns.FacetGrid(data, col="trace_name", height=2.5, col_wrap=3)
g.map(sns.histplot, "shape_parameter", stat='probability')

# %%
g = sns.FacetGrid(data, col="trace_name", height=2.5, col_wrap=3)
g.map(sns.histplot, "cell_area_microns", stat='probability')

# %%
from scipy.stats import kruskal, f_oneway

# %%
ss.kruskal(np.asarray(Gina_a.cell_area_microns),np.asarray(Gina_b.cell_area_microns), np.asarray(Gina_c.cell_area_microns))
# Out:
# KruskalResult(statistic=0.5020751580617846, pvalue=0.7779931347815701)

# %%
f_oneway(np.asarray(Gina_a.cell_area_microns),\
        np.asarray(Gina_b.cell_area_microns), np.asarray(Gina_c.cell_area_microns))
# Out:
# F_onewayResult(statistic=0.22984037648804465, pvalue=0.7947129601476517)

# %%
import scipy.stats as ss
import statsmodels.api as sa
import scikit_posthocs as sp

# %%
areas = [data.loc[ids, 'cell_area_microns'].values for ids in data.groupby('trace_name').groups.values()]
ss.kruskal(*areas)
# Out:
# KruskalResult(statistic=3.230015145482972, pvalue=0.9544730667135525)

# %%
perimeters = [data.loc[ids, 'cell_perimeter_microns'].values for ids in data.groupby('trace_name').groups.values()]
ss.kruskal(*perimeters)
# Out:
# KruskalResult(statistic=5.027344033022018, pvalue=0.8319181239467434)

# %%
circ = [data.loc[ids, 'circularity'].values for ids in data.groupby('trace_name').groups.values()]
ss.kruskal(*circ)
# Out:
# KruskalResult(statistic=3.0217969848126813, pvalue=0.9634245188536351)

# %%
angle = [data.loc[ids, 'major_shape_axis_alignment_rads'].values for ids in data.groupby('trace_name').groups.values()]
ss.kruskal(*angle)
# Out:
# KruskalResult(statistic=6.210575467529082, pvalue=0.7186720268960436)

# %%
data.groupby('trace_name').describe().cell_area_microns
# Out:
#                 count        mean         std         min         25%  \
# trace_name
# Alex a          288.0  406.720821  115.710315   75.880416  328.147008
# Alex b          293.0  405.462062  115.119725   86.761382  331.296761
# Cellpose cyto   301.0  406.664426  113.665069  128.853537  325.856278
# Cellpose cyto2  300.0  406.396420  114.161683   38.656061  324.997254
# Gina a          277.0  410.649452  118.363182  116.827207  337.596267
# Gina b          271.0  408.381712  120.225137   71.298957  328.576519
# Gina c          254.0  415.297317  117.554246  144.602303  338.455291
# Henry           261.0  412.914972  110.171018  184.403729  339.600655
# Sarah           275.0  410.535178  118.808235  126.849149  329.292372
# Tash            291.0  403.921153  119.993806  119.404278  324.281402
#
#                        50%         75%         max
# trace_name
# Alex a          394.434994  472.534554  773.407563
# Alex b          386.846952  469.313216  775.698293
# ...

# %%
data.groupby('trace_name').describe().circularity
# Out:
#                 count      mean       std       min       25%       50%  \
# trace_name
# Alex a          288.0  0.500331  0.186914  0.123002  0.350291  0.464760
# Alex b          293.0  0.492307  0.179916  0.101827  0.345539  0.458147
# Cellpose cyto   301.0  0.508383  0.181484  0.179515  0.355276  0.489182
# Cellpose cyto2  300.0  0.507515  0.183491  0.160704  0.356223  0.483006
# Gina a          277.0  0.494103  0.174328  0.162346  0.352281  0.469709
# Gina b          271.0  0.490073  0.175055  0.147328  0.353768  0.463835
# Gina c          254.0  0.496192  0.181411  0.150834  0.363235  0.471233
# Henry           261.0  0.491600  0.177088  0.143612  0.353111  0.461572
# Sarah           275.0  0.497594  0.177550  0.127383  0.356430  0.473620
# Tash            291.0  0.489383  0.175370  0.137599  0.354518  0.464961
#
#                      75%       max
# trace_name
# Alex a          0.645117  0.970916
# Alex b          0.614945  0.958498
# Cellpose cyto   0.644421  0.970267
# ...

# %%
data.groupby('trace_name').describe().major_shape_axis_alignment_rads
# Out:
#                 count      mean       std       min       25%       50%  \
# trace_name
# Alex a          288.0  1.244754  1.099195  0.005173  0.311582  0.712345
# Alex b          293.0  1.271247  1.131598  0.000857  0.335933  0.685757
# Cellpose cyto   301.0  1.237620  1.095424  0.006446  0.345886  0.710128
# Cellpose cyto2  300.0  1.214233  1.096113  0.000000  0.318550  0.710772
# Gina a          277.0  1.191504  1.113177  0.006728  0.280951  0.639042
# Gina b          271.0  1.186714  1.106242  0.006764  0.307356  0.623306
# Gina c          254.0  1.216287  1.104571  0.005599  0.299677  0.665186
# Henry           261.0  1.220401  1.138059  0.000262  0.312053  0.600000
# Sarah           275.0  1.260697  1.102869  0.003264  0.343863  0.686434
# Tash            291.0  1.327938  1.128721  0.015449  0.351084  0.744344
#
#                      75%       max
# trace_name
# Alex a          2.514777  3.133388
# Alex b          2.646652  3.131937
# Cellpose cyto   2.479011  3.141060
# ...

# %%
apd=sp.posthoc_dunn(data, val_col='shape_parameter', group_col='trace_name')
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}
sp.sign_plot(apd,**heatmap_args)
# Out:
# (<AxesSubplot: >, <matplotlib.colorbar.Colorbar at 0x29ab2004670>)

# %%
pc=sp.posthoc_dunn(data, val_col='cell_perimeter_microns', group_col='trace_name')
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
# Out:
# (<AxesSubplot: >, <matplotlib.colorbar.Colorbar at 0x29ab21f44c0>)

# %%
pc=sp.posthoc_dunn(data, val_col='shape_parameter', group_col='trace_name')
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
# Out:
# (<AxesSubplot: >, <matplotlib.colorbar.Colorbar at 0x29ab1e70100>)

# %%
pc=sp.posthoc_dunn(data, val_col='circularity', group_col='trace_name')
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
# Out:
# (<AxesSubplot: >, <matplotlib.colorbar.Colorbar at 0x29ab29a7280>)

# %%
pc=sp.posthoc_dunn(data, val_col='major_shape_axis_alignment_rads', group_col='trace_name')
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
# Out:
# (<AxesSubplot: >, <matplotlib.colorbar.Colorbar at 0x29ab24e3880>)
