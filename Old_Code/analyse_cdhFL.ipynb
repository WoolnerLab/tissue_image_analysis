# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import seaborn as sns
import os

import cv2

from glob import glob
from matplotlib.patches import  Polygon
from matplotlib.collections import PatchCollection
from scipy.stats import linregress
from scipy.spatial.distance import cdist


from utils import geometry

# %%
pixel_size=1024
micron_size=276.92

in_dir='C:\\Users\\v35431nc\\Documents\\Lab_Stuff\\Code\\tissue_image_analysis\\tissue_image_analysis\\Output\\CdhFL/'



files_s=sorted(glob(in_dir+'/*/*/Data/20161130_1_fr*_cell_data_geometry.csv'))
df=pd.read_csv(files_s[0])
df['frame']=int(files_s[0].split('\\')[-1].split('_')[2][2:])
df['time']=(df['frame']-1)/5
i=1
for f in files_s[1:]:
    data_s=pd.read_csv(f)
    data_s['frame']=int(f.split('\\')[-1].split('_')[2][2:])
    if data_s['frame'][0]==1:
        data_s['time']=0
    else:
        data_s['time']=(data_s['frame']-1)/5
    df=pd.concat([df, data_s], ignore_index=True)
    i+=5

df.to_csv(in_dir+'20161130_1_collated.csv')

# %%
data_s
# Out:
#      cell_id  cell_perimeter_microns  cell_area_microns  shape_parameter  \
# 0        0.0               60.463210         220.528245         4.071544
# 1        1.0               72.592752         288.691521         4.272443
# 2        2.0               52.981386         169.262588         4.072329
# 3        3.0               80.733811         399.814844         4.037625
# 4        4.0               60.949061         223.392248         4.077866
# ..       ...                     ...                ...              ...
# 229    229.0               92.468514         602.299869         3.767797
# 230    230.0              104.808018         688.219965         3.995130
# 231    231.0               93.587915         635.235906         3.713233
# 232    232.0              101.569856         679.914355         3.895271
# 233    233.0              105.036298         766.120851         3.794816
#
#      circularity  cell_edge_count  major_shape_axis_alignment_rads  frame  \
# ...

# %%
df
# Out:
#       cell_id  cell_perimeter_microns  cell_area_microns  shape_parameter  \
# 0         0.0               64.183063         250.313878         4.056747
# 1         1.0               68.946300         265.493095         4.231403
# 2         2.0               75.310063         343.107581         4.065724
# 3         3.0               58.415934         207.067430         4.059527
# 4         4.0               86.119899         451.939702         4.051010
# ...       ...                     ...                ...              ...
# 4110    229.0               92.468514         602.299869         3.767797
# 4111    230.0              104.808018         688.219965         3.995130
# 4112    231.0               93.587915         635.235906         3.713233
# 4113    232.0              101.569856         679.914355         3.895271
# 4114    233.0              105.036298         766.120851         3.794816
#
#       circularity  cell_edge_count  major_shape_axis_alignment_rads  frame  \
# ...

# %%
sns.countplot(data=df,x='cell_edge_count', hue='frame')
plt.legend( loc="upper left", bbox_to_anchor=(1, 1), title='frame')

# %%
sns.histplot(data=df, x='cell_edge_count', hue='time', stat='probability', multiple='dodge', discrete=True, palette=sns.husl_palette( 16), shrink=0.8)
# Out:
# <AxesSubplot: xlabel='cell_edge_count', ylabel='Probability'>

# %%
sns.lineplot(data=df.groupby(['time', 'cell_edge_count']).count(),x='time', y='cell_id', hue='cell_edge_count', palette=sns.hls_palette(7))
# Out:
# <AxesSubplot: xlabel='time', ylabel='cell_id'>

# %%
sns.lineplot(data=df, y='cell_area_microns', x='frame',err_style='bars')
plt.show()
sns.lineplot(data=df, y='cell_perimeter_microns', x='time',err_style='bars')
plt.show()
sns.lineplot(data=df, y='shape_parameter', x='time',err_style='bars', estimator='median')
plt.show()
sns.lineplot(data=df, y='circularity', x='time',err_style='bars')
plt.show()
sns.lineplot(data=df, y='major_shape_axis_alignment_rads', x='time',err_style='bars')
plt.show()

# %%
sns.histplot(data=df, x='major_shape_axis_alignment_rads', hue='time', multiple='layer', histtype='step')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 sns.histplot(data=df, x='major_shape_axis_alignment_rads', hue='time', multiple='layer', histtype='step')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:1432, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421 estimate_kws = dict(
#    1422     stat=stat,
#    1423     bins=bins,
#    (...)
#    1427     cumulative=cumulative,
#    1428 )
#    1430 if p.univariate:
# -> 1432     p.plot_univariate_histogram(
#    1433         multiple=multiple,
#    1434         element=element,
#    1435         fill=fill,
# ...

# %%
df.cell_area_microns.mean()*4.45
# Out:
# 2084.589499865239
